# %%
# %load_ext xdiag_magic
#%reload_ext xdiag_magic

# %%
# %%blockdiag
# {
#     start -> init -> setup -> ready;
#     group {
#         orientation = portrait;
#         color = white
#         init -> defaults -> cfgfile -> consul;
#     }
#     group {
#         orientation = portrait;
#         color = white
#         setup -> spool -> caches;
#         setup -> vagrant -> vagrant_plugins -> vagrant_boxes;
#         setup -> ansible -> ansible_modules -> ansible_galaxy -> ansible_roles;
#     }
#
#     on_trigger -> prepare -> lint -> execute -> persist -> done;
#     group {
#         orientation = portrait;
#         color = white
#         prepare -> check_params -> fetch_plueprint -> fetch_override -> verify_schema;
#     }
#     group {
#         orientation = portrait;
#         color = white
#         execute -> vagrant_up -> vagrant_provision -> ansible_site;
#     }
#     group {
#         orientation = portrait;
#         color = white
#         persist -> facter_run -> combine -> environmnet_json -> STORE;
#     }
# }
